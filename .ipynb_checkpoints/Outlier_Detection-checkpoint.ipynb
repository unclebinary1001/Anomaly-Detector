# %% [markdown]
# ## Setup Project

# %%
pip install tsmoothie
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
print(len(smoother.smooth_data[0]))
# Out:
# 200

# %%
print(data)
# Out:
# [[ 1.02429975e+01 -1.88260115e+01  6.79679964e+01  7.53289418e+00
#   -1.90912338e+01 -8.58751997e+00 -2.92501119e+01 -5.84027817e+01
#   -2.11402832e+01 -1.85911055e+01 -1.63542241e+01 -1.72968689e+01
#   -2.80199924e+01 -6.86451535e+01 -5.06755843e+01  1.34197730e+01
#    1.39950319e+01  2.00697310e+01 -3.81714494e+00  2.29929010e+01
#   -7.41282842e+00  2.86064462e+01  2.84501135e+01  3.67153062e+01
#    6.37237554e+01 -1.39135949e+01  1.17562663e+01 -1.78082117e+01
#   -1.50888561e+01  1.71358682e+01 -3.71552184e+01  5.48816989e+00
#   -4.22476978e+01 -3.97783469e+01 -2.28900704e+01 -4.73287250e+01
#   -3.30087874e+00 -3.32233249e+01 -1.83662989e+01 -3.93255048e+01
#   -3.26795669e+01 -5.02926133e+01 -5.50923932e+01 -8.60826682e+01
#   -4.03912691e+01 -6.31545568e+01 -1.07475536e+01 -9.01078762e+01
#   -5.96991995e+01  1.75390874e+01  4.95826949e+01  8.35874761e+00
#   -1.97294206e+01 -5.79980924e+01  1.53408990e+01  1.33597544e+00
# ...

# %%
help(LowessSmoother)
# Out:
# Help on class LowessSmoother in module tsmoothie.smoother:
#
# class LowessSmoother(_BaseSmoother)
#  |  LowessSmoother(smooth_fraction, iterations=1, batch_size=None, copy=True)
#  |
#  |  LowessSmoother uses LOWESS (locally-weighted scatterplot smoothing)
#  |  to smooth the timeseries. This smoothing technique is a non-parametric
#  |  regression method that essentially fit a unique linear regression
#  |  for every data point by including nearby data points to estimate
#  |  the slope and intercept. The presented method is robust because it
#  |  performs residual-based reweightings simply specifing the number of
#  |  iterations to operate.
#  |
#  |  The LowessSmoother automatically vectorizes, in an efficient way,
#  |  the desired smoothing operation on all the series passed.
#  |
#  |  Parameters
#  |  ----------
#  |  smooth_fraction : float
#  |      Between 0 and 1. The smoothing span. A larger value of smooth_fraction
#  |      will result in a smoother curve.
#  |
# ...

# %%
help(sim_randomwalk)
# Out:
# Help on function sim_randomwalk in module tsmoothie.utils_func:
#
# sim_randomwalk(n_series, timesteps, process_noise, measure_noise, level=None)
#     Generate randomwalks.
#
#     Parameters
#     ----------
#     n_series : int
#         Number of randomwalks to generate.
#
#     timesteps : int
#         How many timesteps every generated randomwalks must have.
#
#     process_noise : int
#         The noise present in randomwalks creation.
#
#     measure_noise : int
#         The noise present in the signals.
#
#     level : int or 1D array-like, default=None
#         The levels of the randomwalks to generate.
#         If a single integer is passed, all the randomwalks have
#         the same levels. If a 1D array-like is passed, the levels
#         of the randomwalks are random sampled from the iterable
#         passed. If None, the levels are set to 0 for all the series.
#
#     Returns
#     -------
#     data : array of shape (series, timesteps)
# ...

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
24,
19,
12,
22,
24,
18,
14,
23,
15,
26,
19,
26,
14,
24,
13,
21,
22,
19,
22,
20,
16,
12,
22,
17,
18,
15,
24,
20,
15,
23,
20,
26,
24,
17,
21,
24,
26,
18,
21])
# plot the smoothed timeseries with intervals
abnormal_flow = np.array([22,
24,
34,
24,
22,
20,
21,
22,
33,
36,
24,
36,
29,
23,
33,
24,
25,
22,
21,
36,
34,
33,
27,
23,
24,
35,
28,
36,
31,
25,
36,
36,
26,
36,
35,
24,
31,
35,
34,
35,
31,
34,
25,
25,
24,
27,
23,
29,
35,
30,
21,
21,
26,
34,
27,
35,
33,
32,
20,
35,
35,
32,
32,
30,
27,
26,
25,
21,
32,
30,
21,
23,
20,
20,
22,
33,
30,
31,
36,
24,
30,
36,
34,
31,
25,
24,
31,
35,
24,
25,
23,
20,
27,
33,
29,
32,
35,
35,
32,
35,
32,
21,
36,
29,
29,
26,
23,
21,
27,
29,
26,
34,
30,
25,
31,
31,
31,
27,
32,
35,
31,
21,
30,
23,
23,
27,
21,
33,
24,
22,
26,
28,
34,
35,
20,
30,
31,
35,
20,
31,
22,
31,
20,
29,
36,
24,
34,
22,
26,
33,
25,
20,
24,
23,
28,
26,
25,
25,
28,
28,
29,
26,
31,
20,
32,
29,
26,
34,
33,
32,
34,
20,
24,
30,
32,
34,
31,
24,
27,
34,
25,
30,
36,
31,
33,
29,
25,
25,
22,
30,
25,
23,
36,
23,
31,
36,
36,
35,
32,
32])
plt.figure(figsize=(18,5))

for i in range(1):

    plt.subplot(1,3,i+1)
    plt.plot(smoother.smooth_data[i], linewidth=3, color='blue')
#     plt.plot(smoother.data[i], '.k')
    plt.plot(abnormal_flow, '.r')
    plt.title(f"Abnormal Flow Rate"); plt.xlabel('time(s)')

    plt.fill_between(range(len(smoother.data[i])), low[i], up[i], alpha=0.3)

# %%
points = smoother.data[0]

# ###Steps
# Step1
# get expected smoother graph using expected datato create smoother 
# Step 2
# record normal data and compare it using expected smoother created
# - there should be no outlier value
# Step 3
# record abnormal data and compare it using expected smoother created
# - there should be mulitple outlier values 
abnormal_flow = np.array([1.6,
7.4,
4.4,
10.3,
0.1,
12.9,
8.8,
11.700000000000001,
14.5,
3.6,
8.6,
11.700000000000001,
9.200000000000001,
14.700000000000001,
6.4,
1.3,
10.0,
1.2000000000000002,
2.2,
14.600000000000001,
11.4,
14.5,
4.1000000000000005,
13.8,
8.1,
11.5,
13.5,
14.9,
10.5,
9.700000000000001,
3.4000000000000004,
4.7,
3.4000000000000004,
12.8,
5.7,
7.4,
0.8,
3.7,
7.300000000000001,
1.3,
4.5,
13.600000000000001,
13.0,
13.8,
14.4,
3.6,
7.2,
1.7000000000000002,
12.0,
6.1000000000000005,
1.4000000000000001,
6.6000000000000005,
4.4,
2.7,
4.4,
13.9,
12.4,
14.5,
12.8,
7.7,
5.9,
6.0,
3.2,
7.0,
7.800000000000001,
14.3,
7.4,
2.7,
4.4,
14.5,
10.700000000000001,
8.700000000000001,
14.9,
8.4,
3.1,
11.3,
1.8,
7.6000000000000005,
6.300000000000001,
7.5,
5.6000000000000005,
12.8,
4.9,
12.600000000000001,
8.6,
5.800000000000001,
12.5,
3.0,
7.4,
11.600000000000001,
4.3,
12.200000000000001,
5.6000000000000005,
1.9000000000000001,
10.200000000000001,
6.1000000000000005,
4.1000000000000005,
14.3,
2.1,
4.5,
7.4,
14.9,
1.8,
1.7000000000000002,
7.7,
13.9,
4.800000000000001,
14.3,
12.8,
13.0,
13.100000000000001,
0.8,
3.2,
0.30000000000000004,
11.100000000000001,
8.8,
3.1,
6.2,
2.1,
13.3,
10.200000000000001,
7.800000000000001,
12.600000000000001,
10.8,
4.9,
5.9,
0.30000000000000004,
0.2,
11.0,
2.0,
9.600000000000001,
2.1,
12.5,
0.8,
9.5,
3.0,
11.8,
6.300000000000001,
9.5,
8.700000000000001,
2.0,
2.2,
1.1,
4.6000000000000005,
5.300000000000001,
12.600000000000001,
13.3,
12.9,
9.8,
1.6,
11.4,
3.9000000000000004,
4.6000000000000005,
2.0,
4.1000000000000005,
4.0,
3.8000000000000003,
1.2000000000000002,
9.1,
6.7,
6.300000000000001,
12.8,
11.3,
4.3,
2.6,
5.9,
9.600000000000001,
2.8000000000000003,
0.7000000000000001,
6.1000000000000005,
1.0,
7.0,
7.2,
1.5,
10.4,
14.200000000000001,
0.6000000000000001,
3.8000000000000003,
2.0,
3.8000000000000003,
13.0,
12.8,
6.300000000000001,
6.0,
7.5,
14.200000000000001,
9.0,
6.6000000000000005,
1.9000000000000001,
8.6,
12.3,
10.700000000000001,
3.0,
14.700000000000001,
1.5,
6.300000000000001,
1.2000000000000002,
13.3,
12.3,
7.800000000000001])
# compare
# compare to new data set
# newData = data from ibm watson iot studio
# new

up_points = up[0]
low_points = low[0]

for i in range(0, len(points)-1):
    
    current_point = points[i]
    current_up = up_points[i]
    current_low = low_points[i]
    if current_point > current_up or current_point < current_low:
        print(f'found an outlier value: {current_point} at time{i}')
# Out:
# found an outlier value: 67.96799638986401 at time2
# found an outlier value: -90.10787623482959 at time47
# found an outlier value: 49.582694863436906 at time50
# found an outlier value: -57.99809235428949 at time53
# found an outlier value: 144.61852928125614 at time59
# found an outlier value: 106.5888923065107 at time72
# found an outlier value: 97.01556356289885 at time96
# found an outlier value: 98.87625301634823 at time138
# found an outlier value: 138.26203172332578 at time149
# found an outlier value: 112.58754283839691 at time157
# found an outlier value: 135.11304297991146 at time166
# found an outlier value: -8.14611615182109 at time170
